# %%
from engine import Value

# %%
x = Value(2)

# %%
x
# Out:
# Value(data=[2],grad=[0])

# %%
p = x*2 + 10
p
# Out:
# Value(data=[14],grad=[0])

# %%
2-x
# Out:
# Value(data=[0],grad=[0])

# %%
x-4
# Out:
# Value(data=[-2],grad=[0])

# %%
x.tanh()
# Out:
# Value(data=[0.964],grad=[0])

# %%
x.sigmoid()
# Out:
# Value(data=[0.8808],grad=[0])

# %%
from graphviz import Digraph


g = Digraph('G', filename='hello.gv')

g.edge('Hello', 'World')

g.view()
# Out:
# 'hello.gv.pdf'
